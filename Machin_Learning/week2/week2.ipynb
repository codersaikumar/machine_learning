# %%
import pandas as pd
df=pd.read_csv("Car_sales.csv")
df.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
num_attributes = df.shape
print("Number of attributes:", num_attributes)
# Out:
# Number of attributes: (157, 15)

# %%
num_rows, num_columns = df.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 157
# Number of columns: 15

# %%
print("Summary Statistics for Numerical Variables:")
print(df.describe())
# Out:
# Summary Statistics for Numerical Variables:
#        Sales in thousands
# count          157.000000
# mean            52.998076
# std             68.029422
# min              0.110000
# 25%             14.114000
# 50%             29.450000
# 75%             67.956000
# max            540.561000

# %%
print("DataFrame Info:")
print(df.info())
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales in thousands   157 non-null    float64
#  3   4-year resale value  157 non-null    object
#  4   Vehicle type         157 non-null    object
#  5   Price in thousands   157 non-null    object
#  6   Engine size          157 non-null    object
#  7   Horsepower           157 non-null    object
#  8   Wheelbase            157 non-null    object
#  9   Width                157 non-null    object
#  10  Length               157 non-null    object
#  11  Curb weight          157 non-null    object
#  12  Fuel capacity        157 non-null    object
#  13  Fuel efficiency      157 non-null    object
#  14  Latest Launch        157 non-null    object
# ...

# %%
df_cleaned = df.drop_duplicates()
print("Number of rows before removing duplicates:", df.shape[0])
print("Number of rows after removing duplicates:",
df_cleaned.shape[0])
# Out:
# Number of rows before removing duplicates: 157
# Number of rows after removing duplicates: 157

# %%
print("Number of missing values in each column:")
print(df.isnull().sum())
# Out:
# Number of missing values in each column:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value     object
# Vehicle type            object
# Price in thousands      object
# Engine size             object
# Horsepower              object
# Wheelbase               object
# Width                   object
# Length                  object
# Curb weight             object
# Fuel capacity           object
# Fuel efficiency         object
# Latest Launch           object
# dtype: object

# %%
print("Missing values before:\n", df.isnull().sum())
df["Sales in thousands"].fillna(df["Sales in thousands"].mean(),
inplace=True)
print("Missing values after:\n", df.isnull().sum())
print(df.head())
# Out:
# Missing values before:
#  Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64
# Missing values after:
#  Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# ...

# %%
import pandas as pd
df=pd.read_csv("Car_sales.csv")

def find_min_max(df,Horsepower):
    min_value = df[Horsepower].min()
    max_value = df[Horsepower].max()
    min_row = df[df[Horsepower] == min_value]
    max_row = df[df[Horsepower] == max_value]
    return min_value,max_value,min_row,max_row

hp_min,hp_max,hp_min_row,hp_max_row = find_min_max(df,"Horsepower")

print("\nHorsepower - Min:", hp_min, "\n", hp_min_row)
print("\nHorsepower - Max:", hp_max, "\n", hp_max_row)
# Out:
# Horsepower - Min: .
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 33  Chrysler       Town & Country                  53.48               19.54
#
#    Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 33          Car                  .           .          .         .     .
#
#    Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# 33      .           .             .               .     13-Jul-15
#
# Horsepower - Max: 92
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 62  Hyundai        Accent                         41.184                5.86
#
#    Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 62    Passenger              9.699         1.5         92      96.1  65.7
#
#    Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# 62  166.7        2.24          11.9              31      9-Oct-14

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))

# %%
plt.hist(df["Horsepower"], bins=30, density=True, alpha=0.6,
color="green", label="Histogram")
# Out:
# (array([0.03763752, 0.0492183 , 0.02895194, 0.02026636, 0.02026636,
#         0.03474233, 0.00868558, 0.01447597, 0.01737116, 0.02026636,
#         0.00868558, 0.01447597, 0.01737116, 0.00579039, 0.00868558,
#         0.00868558, 0.00579039, 0.01737116, 0.01447597, 0.00579039,
#         0.00868558, 0.00868558, 0.01737116, 0.00868558, 0.00868558,
#         0.00868558, 0.01158078, 0.00579039, 0.00579039, 0.01158078]),
#  array([ 0. ,  2.2,  4.4,  6.6,  8.8, 11. , 13.2, 15.4, 17.6, 19.8, 22. ,
#         24.2, 26.4, 28.6, 30.8, 33. , 35.2, 37.4, 39.6, 41.8, 44. , 46.2,
#         48.4, 50.6, 52.8, 55. , 57.2, 59.4, 61.6, 63.8, 66. ]),
#  <BarContainer object of 30 artists>)

# %%
import seaborn as sns

sns.kdeplot(df["Horsepower"], fill=True, color="blue", alpha=0.5,label="KDE")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-b0ea3918cccf> in <module>
#       1 import seaborn as sns
#       2
# ----> 3 sns.kdeplot(df["Horsepower"], fill=True, color="blue", alpha=0.5,label="KDE")
#
# ~/.local/lib/python3.8/site-packages/seaborn/distributions.py in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1677         ax = plt.gca()
#    1678
# -> 1679     p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
#    1680
#    1681     method = ax.fill_between if fill else ax.plot
#
# ~/.local/lib/python3.8/site-packages/seaborn/_base.py in _attach(self, obj, allowed_types, log_scale)
# ...

# %%
import pandas as pd
manufacturer_counts = df.groupby('Manufacturer').size().
print(manufacturer_counts)
# Out:
# Manufacturer
# Acura             4
# Audi              3
# BMW               3
# Buick             4
# Cadillac          5
# Chevrolet         9
# Chrysler          7
# Dodge            11
# Ford             11
# Honda             5
# Hyundai           3
# Infiniti          1
# Jaguar            1
# Jeep              3
# Lexus             6
# Lincoln           3
# Mercedes-Benz     9
# Mercury           6
# Mitsubishi        7
# Nissan            7
# Oldsmobile        6
# Plymouth          4
# Pontiac           6
# Porsche           3
# Saab              2
# Saturn            5
# Subaru            2
# Toyota            9
# Volkswagen        6
# Volvo             6
# dtype: int64

# %%
new = df.drop_duplicates()

# %%
new.shape
# Out:
# (157, 15)

# %%
df.shape
# Out:
# (157, 15)

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
df.describe()
# Out:
#        Sales in thousands
# count          157.000000
# mean            52.998076
# std             68.029422
# min              0.110000
# 25%             14.114000
# 50%             29.450000
# 75%             67.956000
# max            540.561000

# %%
df.info
# Out:
# <bound method DataFrame.info of       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
new = df.isnull().sum().idxmax()

# %%
ndf = df.drop(columns=[new])

# %%
ndf
# Out:
#                  Model  Sales in thousands 4-year resale value Vehicle type  \
# 0    Integra                        16.919               16.36    Passenger
# 1    TL                             39.384              19.875    Passenger
# 2    CL                             14.114              18.225    Passenger
# 3    RL                              8.588              29.725    Passenger
# 4    A4                             20.397              22.255    Passenger
# ..                 ...                 ...                 ...          ...
# 152  V40                             3.545                   .    Passenger
# 153  S70                            15.245                   .    Passenger
# 154  V70                            17.531                   .    Passenger
# 155  C70                             3.493                   .    Passenger
# 156  S80                            18.969                   .    Passenger
#
# ...

# %%
cat_col = df.select_dtypes(include =['object']).columns

# %%
drop_col = df.dropna(axis=0,subset=cat_col)

# %%
drop_col
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
numaric_col = df.select_dtypes(include = ['number']).columns
drop_col = df.dropna(axis=0,subset=numaric_col)
drop_col
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
numaric_col
# Out:
# Index(['Sales in thousands'], dtype='object')

# %%
df.sort_values(by=['Price in thousands'], ascending=[True])
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 2    Acura          CL                             14.114              18.225
# 33   Chrysler       Town & Country                 53.480               19.54
# 129  Saturn         SL                             80.620                 9.2
# 140  Toyota         Tacoma                         84.087               9.575
# 63   Hyundai        Elantra                        66.692               7.825
# ..             ...                ...                 ...                 ...
# 126  Porsche        Carrera Cabriolet               1.866               67.55
# 95   Mercedes-Benz  SL-Class                        3.311                58.6
# 99   Mercedes-Benz  CL500                           0.954                   .
# 26   Chevrolet      Metro                          21.855                5.16
# 62   Hyundai        Accent                         41.184                5.86
#
# ...

# %%
newdf = df[df.isnull().any(axis=1)]

# %%
newdf
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales in thousands, 4-year resale value, Vehicle type, Price in thousands, Engine size, Horsepower, Wheelbase, Width, Length, Curb weight, Fuel capacity, Fuel efficiency, Latest Launch]
# Index: []

# %%
print(df[df.isnull().any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales in thousands, 4-year resale value, Vehicle type, Price in thousands, Engine size, Horsepower, Wheelbase, Width, Length, Curb weight, Fuel capacity, Fuel efficiency, Latest Launch]
# Index: []

# %%
new = df.select_dtypes(include=['number']).columns

# %%
new
# Out:
# Index(['Sales in thousands'], dtype='object')

# %%
new = df.sort_values(by=['Price in thousands'],ascending=[True])

# %%
new.iloc[0:1,:]
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 2  Acura          CL                             14.114              18.225
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 2    Passenger                  .         3.2        225     106.9  70.6
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# 2    192        3.47          17.2              26      1-Apr-14

# %%
def max_min_in_col(column):
    max_value=column.max()
    min_values=column.min()
    return max_value,min_values

max_,min_ = max_min_in_col(df["Horsepower"])

# %%
print(max_)
print(min_)
# Out:
# 92
# .

# %%
def find_min_max(df,Horsepower):
    min_value = df[Horsepower].min()
    max_value = df[Horsepower].max()
    min_row = df[df[Horsepower] == min_value]
    max_row = df[df[Horsepower] == max_value]
    return min_value,max_value,min_row,max_row

hp_min,hp_max,hp_min_row,hp_max_row = find_min_max(df,"Horsepower")

print(hp_min,hp_max)
# Out:
# . 92

# %%
def max_min_in_col(column):
    max_value=column.max()
    min_values=column.min()
    return max_value,min_values

max_hp,min_hp = max_min_in_col(df["Horsepower"])
max_l,min_l = max_min_in_col(df["Length"])
max_fe,min_fe = max_min_in_col(df["Fuel efficiency"])

print(f"horse power:{max_hp,min_hp}")
print(f"length power:{max_l,min_l}")
print(f"fuel effiency:{max_fe,min_fe}")
# Out:
# horse power:('92', '.')
# length power:('224.5', '.')
# fuel effiency:('45', '.')

# %%
# used to find the row for above max and min values

print("for hp")
(df[df['Horsepower'] == max_hp])
# Out:
# for hp
#      Manufacturer              Model  Sales in thousands 4-year resale value  \
# 62  Hyundai        Accent                         41.184                5.86
#
#    Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 62    Passenger              9.699         1.5         92      96.1  65.7
#
#    Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# 62  166.7        2.24          11.9              31      9-Oct-14

# %%
import matplotlib.pyplot as plt
plt.subplots()
plt.hist(df['Horsepower'],bins=40)

plt.show()

# %%
# 14. Plot histogram of continuous numerical variable : price,sales,hoursepower,fuelefficiency

import seaborn as sns


# Select only numerical columns
num_cols = df.select_dtypes(include=['number']).columns
df_num_cols = df[num_cols].dropna()

# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(14, 8))


axes = axes.flatten()  # Flatten to 1D array for easy indexing

# Loop through numerical columns and plot histograms
for i,col in enumerate(num_cols):

    sns.histplot(df_num_cols[col], kde=True, ax=axes[i])

    axes[i].set_title(f"Histogram of {col.capitalize()}")
    axes[i].set_xlabel(col.capitalize())
    axes[i].set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
numaric_col = df.select_dtypes(include=['number']).columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 numaric_col = df.select_dtypes(include=['number']).columns
#
# NameError: name 'df' is not defined

# %%
numaric_col
# Out:
# Index(['Sales in thousands'], dtype='object')

# %%
df['Width'] = pd.to_numeric(df['Width'],errors='coerce')

# %%
numaric_col = df.select_dtypes(include=['number']).columns

# %%
numaric_col
# Out:
# Index(['Sales in thousands', 'Width'], dtype='object')

# %%
numaric_col = df.select_dtypes(include=['number']).columns
fig,axes = plt.subplots(1,3,figsize=(15,5))
axes = axes.flatten()
i=0;
for col in numaric_col:
    axes[i].hist(df[col], bins=30)
    axes[i].set_title(f"graph for {col}")
    axes[i].set_xlabel("width")
    i+=1

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.kdeplot(df['Width'],fill=True,color='blue',alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-61b6820892a6> in <module>
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 sns.kdeplot(df['Width'],fill=True,color='blue',alpha=0.5)
#
# NameError: name 'df' is not defined

# %%
df.groupby(df['Manufacturer']).size().reset_index(name="count")
# Out:
#      Manufacturer  count
# 0   Acura              4
# 1   Audi               3
# 2   BMW                3
# 3   Buick              4
# 4   Cadillac           5
# 5   Chevrolet          9
# 6   Chrysler           7
# 7   Dodge             11
# 8   Ford              11
# 9   Honda              5
# 10  Hyundai            3
# 11  Infiniti           1
# 12  Jaguar             1
# 13  Jeep               3
# 14  Lexus              6
# 15  Lincoln            3
# 16  Mercedes-Benz      9
# 17  Mercury            6
# 18  Mitsubishi         7
# 19  Nissan             7
# 20  Oldsmobile         6
# 21  Plymouth           4
# 22  Pontiac            6
# 23  Porsche            3
# 24  Saab               2
# 25  Saturn             5
# 26  Subaru             2
# 27  Toyota             9
# 28  Volkswagen         6
# 29  Volvo              6

# %%
df.select_dtypes(include=['number']).columns
# Out:
# Index(['Sales in thousands', 'Width'], dtype='object')

# %%
ff = df['Price in thousands'].corr(df['Sales in thousands'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-26f9190287fb> in <module>
# ----> 1 ff = df['Price in thousands'].corr(df['Sales in thousands'])
#
# ~/.local/lib/python3.8/site-packages/pandas/core/series.py in corr(self, other, method, min_periods)
#    2725
#    2726         if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2727             return nanops.nancorr(
#    2728                 this.values, other.values, method=method, min_periods=min_periods
#    2729             )
#
# ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      94             try:
#      95                 with np.errstate(invalid="ignore"):
# ---> 96                     return f(*args, **kwargs)
#      97             except ValueError as e:
#      98                 # we want to transform an object array
#
# ...

# %%
df.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value     object
# Vehicle type            object
# Price in thousands      object
# Engine size             object
# Horsepower              object
# Wheelbase               object
# Width                  float64
# Length                  object
# Curb weight             object
# Fuel capacity           object
# Fuel efficiency         object
# Latest Launch           object
# dtype: object

# %%
x = df['Price in thousands']
y = df['Sales in thousands']

plt.scatter(x,y)
plt.xlabel("hello")
plt.show()

# %%
sns.pairplot(df)
plt.xlabel("hello")
plt.show()

# %%
df.boxplot(column='Sales in thousands',by='Manufacturer')
plt.show()

# %%
num_col = df.select_dtypes(include=['number']).columns

fig,axes=plt.subplots(2,1,figsize=(10,3))

i=0
for col in num_col:
    df.boxplot(column=df[col],by='Manufacturer')
    i+=1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-fa7bcb8d45f7> in <module>
#       5 i=0
#       6 for col in num_col:
# ----> 7     df.boxplot(column=df[col],by='Manufacturer')
#       8     i+=1
#
# ~/.local/lib/python3.8/site-packages/pandas/plotting/_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     505 ):
#     506     plot_backend = _get_plot_backend(backend)
# --> 507     return plot_backend.boxplot_frame(
#     508         self,
#     509         column=column,
#
# ~/.local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     467     import matplotlib.pyplot as plt
#     468
# --> 469     ax = boxplot(
#     470         self,
#     471         column=column,
#
# ...

# %%
x = df.drop(columns=['Sales in thousands'])
y = df['Sales in thousands']

# %%
x
# Out:
#       Manufacturer              Model 4-year resale value Vehicle type  \
# 0    Acura          Integra                         16.36    Passenger
# 1    Acura          TL                             19.875    Passenger
# 2    Acura          CL                             18.225    Passenger
# 3    Acura          RL                             29.725    Passenger
# 4    Audi           A4                             22.255    Passenger
# ..             ...                ...                 ...          ...
# 152  Volvo          V40                                 .    Passenger
# 153  Volvo          S70                                 .    Passenger
# 154  Volvo          V70                                 .    Passenger
# 155  Volvo          C70                                 .    Passenger
# 156  Volvo          S80                                 .    Passenger
#
#     Price in thousands Engine size Horsepower Wheelbase Width Length  \
# ...

# %%
y
# Out:
# 0      16.919
# 1      39.384
# 2      14.114
# 3       8.588
# 4      20.397
#         ...
# 152     3.545
# 153    15.245
# 154    17.531
# 155     3.493
# 156    18.969
# Name: Sales in thousands, Length: 157, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
df['Model'] = lb.fit_transform(df['Model'])

# %%
df
# Out:
#       Manufacturer  Model  Sales in thousands 4-year resale value  \
# 0    Acura             79              16.919               16.36
# 1    Acura            143              39.384              19.875
# 2    Acura             25              14.114              18.225
# 3    Acura            115               8.588              29.725
# 4    Audi               8              20.397              22.255
# ..             ...    ...                 ...                 ...
# 152  Volvo            148               3.545                   .
# 153  Volvo            125              15.245                   .
# 154  Volvo            149              17.531                   .
# 155  Volvo             24               3.493                   .
# 156  Volvo            126              18.969                   .
#
#     Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0      Passenger               21.5         1.8        140     101.2  67.3
# ...

# %%
dfnew = pd.get_dummies(df,columns=['Model'])

# %%
dfnew
# Out:
#       Manufacturer  Sales in thousands 4-year resale value Vehicle type  \
# 0    Acura                      16.919               16.36    Passenger
# 1    Acura                      39.384              19.875    Passenger
# 2    Acura                      14.114              18.225    Passenger
# 3    Acura                       8.588              29.725    Passenger
# 4    Audi                       20.397              22.255    Passenger
# ..             ...                 ...                 ...          ...
# 152  Volvo                       3.545                   .    Passenger
# 153  Volvo                      15.245                   .    Passenger
# 154  Volvo                      17.531                   .    Passenger
# 155  Volvo                       3.493                   .    Passenger
# 156  Volvo                      18.969                   .    Passenger
#
#     Price in thousands Engine size Horsepower Wheelbase Width Length  ...  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x,y,train_size=0.7,random_state=42)

# %%
x_train
# Out:
#       Manufacturer              Model 4-year resale value Vehicle type  \
# 140  Toyota         Tacoma                          9.575          Car
# 11   Buick          Regal                           13.74    Passenger
# 79   Mitsubishi     Mirage                          8.325    Passenger
# 68   Jeep           Cherokee                       13.775          Car
# 149  Volkswagen     GTI                             13.76    Passenger
# ..             ...                ...                 ...          ...
# 71   Lexus          GS300                          32.075    Passenger
# 106  Nissan         Xterra                              .          Car
# 14   Cadillac       DeVille                        22.525    Passenger
# 92   Mercedes-Benz  C-Class                         26.05    Passenger
# 102  Nissan         Altima                         11.295    Passenger
#
#     Price in thousands Engine size Horsepower Wheelbase Width Length  \
# ...

# %%
x_test
# Out:
#       Manufacturer              Model 4-year resale value Vehicle type  \
# 126  Porsche        Carrera Cabriolet               67.55    Passenger
# 45   Dodge          Caravan                        12.025          Car
# 133  Saturn         LS                                  .    Passenger
# 138  Toyota         Avalon                          18.14    Passenger
# 111  Oldsmobile     Aurora                          19.89    Passenger
# 29   Chrysler       Sebring Conv.                   14.18    Passenger
# 95   Mercedes-Benz  SL-Class                         58.6    Passenger
# 97   Mercedes-Benz  SLK230                              .    Passenger
# 94   Mercedes-Benz  S-Class                        50.375    Passenger
# 139  Toyota         Celica                         15.445    Passenger
# 19   Chevrolet      Cavalier                         9.25    Passenger
# 56   Ford           F-Series                       15.075          Car
# ...

# %%
y_train
# Out:
# 140    84.087
# 11     39.350
# 79     26.232
# 68     80.556
# 149     5.596
#         ...
# 71     12.698
# 106    54.158
# 14     63.729
# 92     18.392
# 102    88.094
# Name: Sales in thousands, Length: 109, dtype: float64

# %%
y_test
# Out:
# 126      1.866
# 45     181.749
# 133     49.989
# 138     63.849
# 111     14.690
# 29      32.775
# 95       3.311
# 97       1.526
# 94      16.774
# 139     33.269
# 19     145.519
# 56     540.561
# 15      15.943
# 69     157.040
# 24      17.947
# 30      31.148
# 125      1.280
# 108      1.112
# 155      3.493
# 65      23.713
# 119    131.097
# 18      14.785
# 12      27.851
# 9       17.527
# 31      32.306
# 81      55.616
# 51      63.403
# 128     12.115
# 145      9.761
# 98      11.592
# 150     49.463
# 75      51.238
# 136    142.535
# 55     220.650
# 124      8.982
# 84      11.337
# 105     42.574
# 42      31.038
# 67      55.557
# 127      9.191
# 26      21.855
# 135     33.028
# 78      22.925
# 148      9.569
# 36       4.734
# 76      13.798
# 22      42.593
# 132      8.472
# Name: Sales in thousands, dtype: float64
