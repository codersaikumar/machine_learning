# %%
#1 Import the dataset (Housing.csv) and look at the top five rows
import pandas as pd  
df = pd.read_csv('Housing.csv')
print(df.head())
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
#2 Check the shape of the DataFrame (rows, columns)
print(df.shape)
# Out:
# (545, 13)

# %%
print(df['price'].dtypes)
# Out:
# int64

# %%
print(df.dtypes)#3 Look at the data types of the columns
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
#checking the if any null values in the dataset and there count
print(df.isnull().sum())
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
#fill thr dataset if any null values with 0 
df.fillna(0,inplace=True)#4 Check for missing  values if any, replace with appropriate values
df['price'].fillna(df['price'].mean(), inplace=True)  #replacing by mean value og the column

#5 Prepare  X (independent variables) and y (dependent variable)

x = df.drop(columns=['price'])
y = df['price']

# %%
arr = x.columns.tolist()

# %%
#6 Visualise the relationship between the independent variables and the depenedent variable using scatterplots
import matplotlib.pyplot as plt
fig,axes = plt.subplots(3,3,figsize=(10,5))
axes=axes.flatten()

for i,col in enumerate(arr):
    sns.scatterplot(data=df,x=col,y="price")
    axes[i].set_title(f"Price Vs {col}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 8
#       6 for i,col in enumerate(arr):
#       7     sns.scatterplot(data=df,x=col,y="price")
# ----> 8     axes[i].set_title(f"Price Vs {col}")
#
# IndexError: index 9 is out of bounds for axis 0 with size 9

# %%
#7 Encoding categorical data in X
import pandas as pd  
df = pd.read_csv('Housing.csv')
x_encoded = df.drop("price", axis=1)
print("Encoded X dataset:")
print(x_encoded.head())
# Out:
# Encoded X dataset:
#    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  7420         4          2        3      yes        no       no
# 1  8960         4          4        4      yes        no       no
# 2  9960         3          2        2      yes        no      yes
# 3  7500         4          2        2      yes        no      yes
# 4  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
print(df.head())
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
x = df.drop(columns=['price'])
y = df['price']

# %%
import matplotlib.pyplot as plt

num_col = df.select_dtypes(include=['number']).columns
fig,axes = plt.subplots(3,2,figsize=(25,15))
axes=axes.flatten()
#num_col = num_col.drop(columns=['price'])
num_col = num_col.drop('price')
i=0
for col in num_col:
    axes[i].scatter(x=df[col],y=y,label="plot")
    axes[i].set_title(f"{col} graph")
    axes[i].set_xlabel("shp")
    axes[i].legend()
    i+=1

plt.delaxes(axes[-1])
plt.tight_layout()  
plt.show()

# %%
cat_col = x.select_dtypes(include=['object'])
cat_col
# Out:
#     mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# 0        yes        no       no              no             yes      yes
# 1        yes        no       no              no             yes       no
# 2        yes        no      yes              no              no      yes
# 3        yes        no      yes              no             yes      yes
# 4        yes       yes      yes              no             yes       no
# ..       ...       ...      ...             ...             ...      ...
# 540      yes        no      yes              no              no       no
# 541       no        no       no              no              no       no
# 542      yes        no       no              no              no       no
# 543       no        no       no              no              no       no
# 544      yes        no       no              no              no       no
#
#     furnishingstatus
# 0          furnished
# 1          furnished
# 2     semi-furnished
# ...

# %%
from sklearn.preprocessing import LabelEncoder

lb = LabelEncoder()
cat_col = x.select_dtypes(include=['object'])
for col in cat_col:
    x[col] = lb.fit_transform(cat_col[col])

# %%
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
col = x.select_dtypes(include=['number']).columns
x[col] = sc.fit_transform(x[col])
x.head()
# Out:
#        area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 0  1.046726  1.403419   1.421812  1.378217  0.405623  -0.465315 -0.734539
# 1  1.757010  1.403419   5.405809  2.532024  0.405623  -0.465315 -0.734539
# 2  2.218232  0.047278   1.421812  0.224410  0.405623  -0.465315  1.361397
# 3  1.083624  1.403419   1.421812  0.224410  0.405623  -0.465315  1.361397
# 4  1.046726  1.403419  -0.570187  0.224410  0.405623   2.149083  1.361397
#
#    hotwaterheating  airconditioning   parking  prefarea  furnishingstatus
# 0        -0.219265         1.472618  1.517692  1.804941         -1.406286
# 1        -0.219265         1.472618  2.679409 -0.554035         -1.406286
# 2        -0.219265        -0.679063  1.517692  1.804941         -0.091662
# 3        -0.219265         1.472618  2.679409  1.804941         -1.406286
# 4        -0.219265         1.472618  1.517692 -0.554035         -1.406286

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x.dtypes
# Out:
# area                int64
# bedrooms            int64
# bathrooms           int64
# stories             int64
# mainroad            int64
# guestroom           int64
# basement            int64
# hotwaterheating     int64
# airconditioning     int64
# parking             int64
# prefarea            int64
# furnishingstatus    int64
# dtype: object

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pridt=lr.predict(x_test)
y_pridt[:5]
# Out:
# array([2686482.50369747, 3481837.17536655, 3244891.67792161,
#        3922187.23944468, 3310555.06277942])

# %%
y_pridt-y_test
# Out:
# 509    2.596769e+06
# 291    1.970770e+04
# 139    7.803606e+05
# 92     4.140149e+05
# 66    -5.437559e+05
#            ...
# 71    -5.761137e+04
# 288    5.146806e+05
# 486    5.445202e+05
# 381    1.725260e+05
# 528    5.928549e+03
# Name: price, Length: 164, dtype: float64

# %%
from sklearn.metrics import mean_squared_error,r2_score
mean_squared_error(y_pridt,y_test)
# Out:
# 1128529514265.9092
